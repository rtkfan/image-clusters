# %%
from clustimage import Clustimage

# %%
# init with default parameters
cl = Clustimage()

# %%
# import the data
imported_data = cl.import_data('./images/')
# Out:
# [clustimage] >INFO> Extracting images from: [./images/]
# [clustimage] >INFO> [627] files are collected recursively from path: [./images/]
# [clustimage] >INFO> [627] images are extracted.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 627/627 [00:05<00:00, 119.21it/s]

# %%
results = cl.fit_transform(imported_data, min_clust=10, max_clust=150)

# %%
cl.clusteval.plot()
# Out:
# (<Figure size 1500x800 with 1 Axes>,
#  <Axes: xlabel='Nr. clusters', ylabel='Score'>)
